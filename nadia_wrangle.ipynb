# %%
import pandas as pd
import src.wrangle as wr

# %%
from importlib import reload

# %%
reload(wr)
# Out:
# <module 'src.wrangle' from '/Users/nadina/codeup-data-science/cisco-time-series-analysis/src/wrangle.py'>

# %%
wr.get_cisco_data()
# Out:
#          fiscal_year                                   customer_name  \
# 981291          2021               Texas Department of Public Safety
# 981292          2021               Texas Department of Public Safety
# 981293          2021               Texas Department of Public Safety
# 981294          2021               Texas Department of Public Safety
# 981295          2021               Texas Department of Public Safety
# ...              ...                                             ...
# 7367053         2023  Lamar Consolidated Independent School District
# 7367054         2023  Lamar Consolidated Independent School District
# 7367055         2023  Lamar Consolidated Independent School District
# 7367056         2023  Lamar Consolidated Independent School District
# 7367057         2023  Lamar Consolidated Independent School District
#
#                  vendor_name  purchase_amount contract_number  \
# 981291   Cisco Systems, Inc.          2657.25    DIR-TSO-4167
# ...
